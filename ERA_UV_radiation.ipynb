# %% [markdown]
# # Import ERA-5 Climate data and filter by trap locations to reduce size

# %%
import numpy as np
from datetime import datetime

# %%
import pandas as pd

# %%
import xarray as xr
import flox
# Out:
# /Users/katherinedixon/anaconda3/lib/python3.7/site-packages/dask/config.py:161: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}

# %%
faz = xr.open_dataset("/Volumes/My Book/Climate/UV/ERA/Arizona_UV_allT.nc", decode_times = True)
fco = xr.open_dataset("/Volumes/My Book/Climate/UV/ERA/Colorado_UV_allT.nc", decode_times = True)
fnm = xr.open_dataset("/Volumes/My Book/Climate/UV/ERA/NewMexico_UV_allT.nc", decode_times = True)
fpnw = xr.open_dataset("/Volumes/My Book/Climate/UV/ERA/PNW_UV_allT.nc", decode_times = True)
fpnw2 = xr.open_dataset("/Volumes/My Book/Climate/UV/ERA/PNW_UV_newT.nc", decode_times = True)

# %%
fca = xr.open_dataset("/Volumes/My Book/Climate/UV/ERA/California_UV_allT.nc", decode_times = True)

# %%
fmissing1 = xr.open_dataset("/Volumes/My Book/Climate/missing_updates//OR_UV_missing1_ay.nc", decode_times = True)
fmissing2 = xr.open_dataset("/Volumes/My Book/Climate/missing_updates//OR_UV_missing2_ay.nc", decode_times = True)

# %%
fpnw.msdwuvrf

# %%
trap_data = pd.read_csv("/Volumes/My Book/Synchrony/_data/ll_info_23.csv")

# %%
def downsample_df(dataset):
    
    # faster to do this on the xarray
    dataset['year'] = dataset['time'].dt.strftime('%Y')
    dataset['month'] = dataset['time'].dt.strftime('%B')
    dataset['day'] = dataset['time'].dt.strftime('%d')
    dataset['time'] = dataset['time'].dt.strftime('%r')
    
    df = dataset.to_dataframe()
    df = df.reset_index()
    
    return(df)

# %%
dfaz = downsample_df(faz)
dfco = downsample_df(fco)
dfnm = downsample_df(fnm)
dfpnw = downsample_df(fpnw)

# %%
dfca = downsample_df(fca)
dfpnw2 = downsample_df(fpnw2)

# %%
dfmissing1 = downsample_df(fmissing1)
dfmissing2 = downsample_df(fmissing2)

# %%
max(dfpnw.longitude)

# %%
dfaz.to_csv("/Volumes/My Book/Climate/UV/downsampled/Arizona_UV_allyearsT.csv")
dfco.to_csv("/Volumes/My Book/Climate/UV/downsampled/Colorado_UV_allyearsT.csv")
dfnm.to_csv("/Volumes/My Book/Climate/UV/downsampled/NewMexico_UV_allyearsT.csv")
dfpnw.to_csv("/Volumes/My Book/Climate/UV/downsampled/PNW_UV_allyearsT.csv")

# %%
dfca.to_csv("/Volumes/My Book/Climate/UV/downsampled/California_UV_allyears_allT.csv")

# %%
dfpnw2.to_csv("/Volumes/My Book/Climate/UV/downsampled/PNW_UV_allyears_newT.csv")

# %%
df_all = pd.concat([dfaz,dfco,dfnm,dfpnw,dfca,dfpnw2])

# %%
df_all = pd.concat([dfmissing1,dfmissing2])

# %% [markdown]
# ### Filtering by traps in the state

# %%
state_df = trap_data.reset_index(drop=True)

# %%
trap_lats = state_df.lat
trap_lons = state_df.lon

print(trap_lats)
# Out:
# 0       34.452258
# 1       34.429790
# 2       33.861750
# 3       33.816588
# 4       33.812968
#           ...
# 1771    45.897575
# 1772    45.861841
# 1773    45.826436
# 1774    45.893359
# 1775    45.617810
# Name: lat, Length: 1776, dtype: float64

# %%
min(trap_lats)
# Out:
# 32.427858

# %%
grid_lon = list(set(df_all.longitude))
grid_lat = list(set(df_all.latitude))

# %%
lat_coord = []

for t in range(0,len(trap_lats)):
    lat_coord.append(grid_lat[np.where(abs(trap_lats[t]- grid_lat) == min(abs(trap_lats[t]- grid_lat)))[0][0]])
    
lon_coord = []

for t in range(0,len(trap_lats)):
    lon_coord.append(grid_lon[np.where(abs(trap_lons[t]- grid_lon) == min(abs(trap_lons[t]- grid_lon)))[0][0]])

# %%
print(min(lat_coord),max(lat_coord))
print(min(lon_coord),max(lon_coord))
# Out:
# 32.5 51.5
# -123.75 -104.75

# %%
coord_df = pd.DataFrame({'lat' : trap_lats, 'lon' : trap_lons,
             'lat_coord' : lat_coord, 'lon_coord': lon_coord})

# %%
coord_df

# %%
state_df = pd.merge(state_df,coord_df)

# %%
state_df["key"] = state_df["lat_coord"].astype(str) + state_df["lon_coord"].astype(str)

# %%
state_keys = list(set(state_df.key))

# %%
state_keys
# Out:
# ['39.5-105.0',
#  '50.75-120.5',
#  '48.5-120.5',
#  '44.0-115.75',
#  '48.5-117.75',
#  '47.75-118.25',
#  '39.25-106.75',
#  '44.5-120.0',
#  '44.5-117.0',
#  '50.25-120.5',
#  '42.25-123.5',
#  '44.25-117.25',
#  '50.5-121.25',
#  '48.25-119.25',
#  '48.25-120.5',
#  '38.5-120.5',
#  '48.75-118.25',
#  '44.75-119.75',
#  '35.25-106.5',
#  '44.25-119.25',
#  '47.25-116.5',
#  '46.0-121.25',
#  '45.0-117.25',
#  '40.25-121.5',
#  '45.25-121.75',
#  '38.5-120.0',
#  '42.75-121.25',
#  '47.25-120.75',
#  '47.75-114.0',
#  '45.5-121.5',
#  '44.75-118.5',
#  '44.25-119.5',
#  '48.75-119.75',
#  '51.25-121.5',
#  '48.25-120.75',
#  '49.25-119.75',
#  '45.0-118.0',
#  '34.25-117.0',
#  '40.0-120.5',
#  '42.0-122.25',
#  '49.75-119.5',
#  '42.25-123.25',
#  '45.75-117.0',
#  '43.75-121.75',
#  '48.25-120.0',
#  '39.25-106.0',
#  '49.25-120.0',
#  '45.25-116.75',
#  '44.75-118.25',
#  '48.75-118.75',
#  '46.25-117.25',
#  '48.5-119.25',
#  '45.25-117.0',
#  '47.5-121.0',
#  '48.25-117.75',
#  '48.0-117.25',
#  '44.75-115.5',
#  '43.0-116.75',
#  '44.75-115.75',
#  '45.0-117.5',
#  '46.0-116.5',
#  '44.5-119.75',
#  '45.75-117.25',
#  '47.25-114.25',
#  '44.0-119.25',
#  '47.0-114.5',
#  '42.0-122.0',
#  '48.0-120.0',
#  '46.75-116.5',
#  '39.0-106.25',
#  '46.5-115.75',
#  '45.0-119.0',
#  '44.5-117.25',
#  '46.25-117.5',
#  '46.75-114.0',
#  '46.75-116.75',
#  '34.5-111.25',
#  '36.0-106.75',
#  '39.0-120.25',
#  '37.5-119.5',
#  '43.0-121.5',
#  '48.5-118.5',
#  '44.75-119.25',
#  '34.5-110.75',
#  '46.0-120.5',
#  '51.0-121.0',
#  '49.5-120.25',
#  '42.25-120.5',
#  '45.25-117.25',
#  '45.25-117.75',
#  '49.0-117.5',
#  '46.5-114.25',
#  '39.0-120.0',
#  '48.0-120.25',
#  '44.25-121.75',
#  '45.75-118.0',
#  '47.0-116.75',
#  '45.0-120.0',
#  '44.0-119.0',
#  '44.75-117.0',
#  '43.75-115.5',
#  '44.75-116.5',
#  '45.25-118.5',
#  '46.5-121.25',
#  '46.75-115.5',
#  '42.25-122.0',
#  '51.5-122.25',
#  '42.5-121.75',
#  '48.5-120.25',
#  '48.25-114.25',
#  '36.25-118.75',
#  '44.25-120.5',
#  '47.5-120.25',
#  '42.0-120.75',
#  '45.5-114.0',
#  '39.0-105.5',
#  '44.75-119.0',
#  '46.0-116.75',
#  '43.5-114.75',
#  '46.25-121.25',
#  '40.0-120.75',
#  '44.5-119.0',
#  '43.25-121.75',
#  '46.75-117.25',
#  '46.0-117.5',
#  '42.0-120.5',
#  '45.5-118.5',
#  '46.5-121.0',
#  '35.75-105.75',
#  '45.0-117.0',
#  '46.0-121.0',
#  '42.0-123.5',
#  '46.25-120.75',
#  '45.75-115.75',
#  '48.75-118.5',
#  '48.25-119.75',
#  '47.75-117.25',
#  '47.5-116.75',
#  '33.25-110.75',
#  '48.25-119.0',
#  '39.5-121.0',
#  '45.0-116.25',
#  '46.25-121.0',
#  '44.5-117.75',
#  '39.5-120.25',
#  '43.75-116.0',
#  '35.75-106.75',
#  '47.25-117.0',
#  '44.75-116.25',
#  '34.25-111.0',
#  '47.5-117.0',
#  '40.75-121.75',
#  '45.25-118.75',
#  '38.25-120.5',
#  '47.25-121.0',
#  '44.5-121.75',
#  '32.75-109.75',
#  '47.75-116.75',
#  '48.75-117.5',
#  '44.0-115.5',
#  '45.25-114.5',
#  '35.5-105.75',
#  '45.75-116.25',
#  '44.5-121.5',
#  '45.5-117.5',
#  '42.25-122.25',
#  '48.25-120.25',
#  '44.5-120.5',
#  '37.5-119.75',
#  '40.5-121.5',
#  '46.25-115.75',
#  '46.25-117.75',
#  '51.0-120.25',
#  '42.5-122.25',
#  '47.5-121.25',
#  '47.75-116.5',
#  '45.0-118.75',
#  '47.0-116.5',
#  '48.75-117.75',
#  '50.75-121.25',
#  '48.75-120.5',
#  '46.0-115.75',
#  '44.75-118.0',
#  '47.0-113.5',
#  '43.0-121.0',
#  '47.0-117.25',
#  '49.0-119.75',
#  '45.0-119.5',
#  '44.5-115.75',
#  '34.0-109.5',
#  '36.5-118.75',
#  '44.25-116.0',
#  '46.75-117.0',
#  '50.5-120.0',
#  '45.75-115.5',
#  '44.25-119.0',
#  '47.25-114.5',
#  '38.75-104.75',
#  '36.0-118.5',
#  '42.25-121.0',
#  '42.5-116.5',
#  '42.75-121.5',
#  '48.75-119.25',
#  '42.25-120.75',
#  '45.5-118.25',
#  '47.5-120.5',
#  '48.0-119.0',
#  '51.25-121.25',
#  '40.0-121.25',
#  '49.0-118.25',
#  '46.5-116.0',
#  '48.0-120.75',
#  '47.75-120.75',
#  '51.0-121.75',
#  '45.25-121.5',
#  '48.75-117.25',
#  '47.75-120.5',
#  '50.75-120.0',
#  '48.0-117.0',
#  '38.75-120.25',
#  '44.5-120.25',
#  '45.25-117.5',
#  '44.25-118.75',
#  '44.0-118.5',
#  '42.25-123.0',
#  '32.75-105.75',
#  '43.25-111.25',
#  '44.25-119.75',
#  '45.0-121.75',
#  '44.5-118.0',
#  '47.75-117.0',
#  '38.25-119.75',
#  '42.25-121.25',
#  '47.0-116.0',
#  '45.5-116.5',
#  '48.0-120.5',
#  '42.75-122.0',
#  '45.5-116.25',
#  '40.0-121.0',
#  '46.75-116.25',
#  '47.0-114.25',
#  '46.0-115.5',
#  '34.5-112.5',
#  '48.0-118.75',
#  '48.5-119.0',
#  '39.25-120.0',
#  '46.0-113.0',
#  '36.75-119.0',
#  '39.25-105.25',
#  '50.75-121.0',
#  '44.25-120.25',
#  '44.75-120.0',
#  '39.75-121.0',
#  '48.5-118.0',
#  '50.75-120.25',
#  '43.5-114.5',
#  '39.5-120.75',
#  '45.25-119.0',
#  '49.0-119.0',
#  '46.75-121.0',
#  '48.0-114.0',
#  '37.75-119.5',
#  '47.75-114.25',
#  '39.5-120.5',
#  '43.0-116.5',
#  '44.5-116.25',
#  '37.25-119.5',
#  '42.25-113.5',
#  '44.25-115.5',
#  '32.75-105.5',
#  '45.0-121.5',
#  '32.75-110.0',
#  '34.0-109.25',
#  '48.5-120.0',
#  '49.5-119.75',
#  '46.0-120.75',
#  '38.25-120.25',
#  '39.25-120.5',
#  '45.0-116.75',
#  '43.75-118.75',
#  '51.0-121.25',
#  '48.0-114.5',
#  '44.5-119.5',
#  '43.0-121.25',
#  '44.5-120.75',
#  '44.75-116.75',
#  '42.0-123.75',
#  '47.5-117.25',
#  '44.5-118.5',
#  '42.75-123.0',
#  '44.25-115.75',
#  '44.5-116.0',
#  '49.0-118.75',
#  '51.25-121.75',
#  '45.0-119.75',
#  '42.75-122.75',
#  '39.25-105.0',
#  '45.0-116.5',
#  '49.0-119.25',
#  '41.5-120.25',
#  '34.5-117.0',
#  '47.25-114.0',
#  '48.25-118.75',
#  '42.75-116.75',
#  '44.25-118.0',
#  '46.25-115.5',
#  '45.25-114.0',
#  '48.0-117.5',
#  '43.25-121.25',
#  '36.0-118.75',
#  '45.75-117.5',
#  '34.5-111.5',
#  '46.0-118.0',
#  '36.75-118.75',
#  '43.25-121.5',
#  '43.5-121.5',
#  '42.75-121.0',
#  '48.75-120.25',
#  '42.75-120.75',
#  '37.75-119.75',
#  '47.75-118.75',
#  '48.5-117.5',
#  '42.25-121.75',
#  '44.25-118.5',
#  '47.25-121.25',
#  '46.75-114.25',
#  '50.75-120.75',
#  '48.5-119.75',
#  '38.5-120.25',
#  '42.5-121.5',
#  '38.25-120.0',
#  '45.25-119.25',
#  '44.75-118.75',
#  '36.25-105.5',
#  '42.5-123.0',
#  '45.0-114.25',
#  '46.75-121.25',
#  '40.5-120.75',
#  '39.25-120.75',
#  '48.75-119.5',
#  '45.25-121.25',
#  '44.5-119.25',
#  '44.0-120.25',
#  '37.25-105.0',
#  '45.25-118.25',
#  '50.75-119.75',
#  '43.5-114.25',
#  '42.5-121.25',
#  '43.5-113.5',
#  '41.5-120.5',
#  '46.25-118.0',
#  '48.5-118.75',
#  '42.5-121.0',
#  '49.0-117.25',
#  '45.0-109.25',
#  '42.75-121.75',
#  '48.25-118.5',
#  '48.0-118.0',
#  '42.0-120.25',
#  '39.0-105.0',
#  '43.5-115.25',
#  '32.5-110.75',
#  '43.0-121.75',
#  '43.75-115.25',
#  '45.75-117.75',
#  '44.5-118.75',
#  '45.75-121.75',
#  '48.25-118.0',
#  '43.0-120.75',
#  '44.0-118.75',
#  '47.0-121.25',
#  '49.0-119.5',
#  '47.5-116.5',
#  '44.75-116.0',
#  '38.0-120.0',
#  '34.0-107.25',
#  '40.25-121.25',
#  '43.0-122.0',
#  '47.0-116.25',
#  '42.5-123.25',
#  '40.25-120.75',
#  '39.25-120.25',
#  '42.5-122.0',
#  '47.0-117.0',
#  '36.0-106.5',
#  '47.75-117.5',
#  '41.5-121.0',
#  '46.0-117.75',
#  '45.0-118.5',
#  '43.75-114.5',
#  '48.5-116.25',
#  '42.0-121.25',
#  '47.0-121.0',
#  '33.0-105.75',
#  '42.5-123.5',
#  '48.5-117.25',
#  '47.25-120.5',
#  '47.25-116.25',
#  '47.75-121.0',
#  '44.25-116.25',
#  '44.75-119.5',
#  '43.5-115.0',
#  '46.25-116.75',
#  '45.5-116.75',
#  '48.75-119.0',
#  '43.75-111.5',
#  '45.25-118.0',
#  '47.5-120.75',
#  '43.25-122.0',
#  '46.75-116.0',
#  '42.5-120.75',
#  '38.75-120.5',
#  '39.5-105.25',
#  '48.25-117.25',
#  '48.75-118.0',
#  '39.0-120.5',
#  '34.25-116.75',
#  '45.5-121.75',
#  '48.25-117.5',
#  '51.25-121.0',
#  '47.75-118.0',
#  '42.25-122.5',
#  '50.5-119.25',
#  '35.75-118.5',
#  '42.0-122.5',
#  '45.0-119.25',
#  '44.5-118.25',
#  '45.0-116.0',
#  '42.5-122.5',
#  '45.5-117.25',
#  '48.0-118.25',
#  '44.25-118.25',
#  '48.0-117.75',
#  '49.0-118.5',
#  '42.75-116.5',
#  '45.25-119.5',
#  '50.0-119.5',
#  '46.75-120.75',
#  '49.25-120.25',
#  '47.0-120.75',
#  '48.0-118.5',
#  '49.0-121.0',
#  '48.5-118.25',
#  '45.75-118.25',
#  '47.75-120.25',
#  '47.75-117.75',
#  '45.5-118.0',
#  '48.25-117.0',
#  '45.0-117.75',
#  '47.25-120.25',
#  '33.0-105.5',
#  '42.5-120.5',
#  '47.25-116.75',
#  '33.75-111.0',
#  '42.25-120.25',
#  '51.0-121.5',
#  '46.0-117.25',
#  '50.25-119.25',
#  '44.0-119.5',
#  '39.0-105.25',
#  '38.75-105.0',
#  '47.0-114.0',
#  '39.0-104.75',
#  '45.0-120.25',
#  '46.0-121.5',
#  '48.0-116.75',
#  '45.5-117.75']

# %%
df_all["key"] = df_all["latitude"].astype(str) + df_all["longitude"].astype(str)

# %%
df_all
# Out:
#           longitude  latitude         time   msdwuvrf  year     month day  \
# 0            -112.5      34.5  05:00:00 AM   0.000000  1979   January  01
# 1            -112.5      34.5  09:00:00 PM  57.258343  1979   January  01
# 2            -112.5      34.5  05:00:00 AM   0.000000  1979   January  02
# 3            -112.5      34.5  09:00:00 PM  49.625664  1979   January  02
# 4            -112.5      34.5  05:00:00 AM   0.000000  1979   January  03
# ...             ...       ...          ...        ...   ...       ...  ..
# 10420555     -109.0      42.0  09:00:00 PM  24.538761  2023  November  23
# 10420556     -109.0      42.0  05:00:00 AM   0.000000  2023  November  24
# 10420557     -109.0      42.0  09:00:00 PM  33.832100  2023  November  24
# 10420558     -109.0      42.0  05:00:00 AM   0.000000  2023  November  25
# 10420559     -109.0      42.0  09:00:00 PM  47.944698  2023  November  25
#
#           expver         key
# 0            NaN  34.5-112.5
# 1            NaN  34.5-112.5
# 2            NaN  34.5-112.5
# 3            NaN  34.5-112.5
# 4            NaN  34.5-112.5
# ...          ...         ...
# 10420555     5.0  42.0-109.0
# 10420556     5.0  42.0-109.0
# 10420557     5.0  42.0-109.0
# 10420558     5.0  42.0-109.0
# 10420559     5.0  42.0-109.0
#
# [119034840 rows x 9 columns]

# %%
trap_all = df_all[df_all['key'].isin(state_keys)]

# %%
trap_all
# Out:
#           longitude  latitude         time   msdwuvrf  year     month day  \
# 0           -112.50      34.5  05:00:00 AM   0.000000  1979   January  01
# 1           -112.50      34.5  09:00:00 PM  57.258343  1979   January  01
# 2           -112.50      34.5  05:00:00 AM   0.000000  1979   January  02
# 3           -112.50      34.5  09:00:00 PM  49.625664  1979   January  02
# 4           -112.50      34.5  05:00:00 AM   0.000000  1979   January  03
# ...             ...       ...          ...        ...   ...       ...  ..
# 10196047    -109.25      45.0  09:00:00 PM  17.823833  2023  November  23
# 10196048    -109.25      45.0  05:00:00 AM   0.000000  2023  November  24
# 10196049    -109.25      45.0  09:00:00 PM  37.186699  2023  November  24
# 10196050    -109.25      45.0  05:00:00 AM   0.000000  2023  November  25
# 10196051    -109.25      45.0  09:00:00 PM  40.930351  2023  November  25
#
#           expver          key
# 0            NaN   34.5-112.5
# 1            NaN   34.5-112.5
# 2            NaN   34.5-112.5
# 3            NaN   34.5-112.5
# 4            NaN   34.5-112.5
# ...          ...          ...
# 10196047     5.0  45.0-109.25
# 10196048     5.0  45.0-109.25
# 10196049     5.0  45.0-109.25
# 10196050     5.0  45.0-109.25
# 10196051     5.0  45.0-109.25
#
# [15903256 rows x 9 columns]

# %%
trap_all.to_csv("/Volumes/My Book/Climate/UV/downsampled/trap_uv_data_allT.csv")

# %%
trap_all.to_csv("/Volumes/My Book/Climate/UV/downsampled/trap_uv_data_missing.csv")

# %% [markdown]
# ## Forgot about California when doing this before

# %%
### Filtering by traps in the state

state_df = trap_data.loc[trap_data['State'] == "CA"] 

state_df = state_df.reset_index(drop=True)

trap_lats = state_df.lat
trap_lons = state_df.lon

print(trap_lats)

min(trap_lats)

grid_lon = list(set(dfca.longitude))
grid_lat = list(set(dfca.latitude))

lat_coord = []

for t in range(0,len(trap_lats)):
    lat_coord.append(grid_lat[np.where(abs(trap_lats[t]- grid_lat) == min(abs(trap_lats[t]- grid_lat)))[0][0]])
    
lon_coord = []

for t in range(0,len(trap_lats)):
    lon_coord.append(grid_lon[np.where(abs(trap_lons[t]- grid_lon) == min(abs(trap_lons[t]- grid_lon)))[0][0]])

print(lat_coord)
print(lon_coord)


coord_df = pd.DataFrame({'lat' : trap_lats, 'lon' : trap_lons,
             'lat_coord' : lat_coord, 'lon_coord': lon_coord})

state_df = pd.merge(state_df,coord_df)

state_df["key"] = state_df["lat_coord"].astype(str) + state_df["lon_coord"].astype(str)

state_keys = list(set(state_df.key))

state_df

# %%
dfca["key"] = dfca["latitude"].astype(str) + dfca["longitude"].astype(str)

cali = dfca[dfca['key'].isin(state_keys)]

cali = cali.reset_index(drop=True)

cali

# %%
cali.to_csv("/Volumes/My Book/Climate/UV/downsampled/cali_uv_data.csv")
